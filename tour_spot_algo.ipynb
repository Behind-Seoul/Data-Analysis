# %%
import pandas as pd
from collections import defaultdict
from collections import Counter

# %%
# 서울시 공공자전거 대여 이력 정보
bike = pd.read_csv('data/bike.csv', encoding='cp949')
bike.head()
# Out:
#        자전거번호                 대여일시  대여 대여소번호 대여 대여소명  대여거치대  \
# 0  SPB-53035  2021-12-01 09:45:56         3    중랑센터      0
# 1  SPB-40999  2021-12-05 16:02:31         3    중랑센터      0
# 2  SPB-55934  2021-12-10 22:01:39         3    중랑센터      0
# 3  SPB-50913  2021-12-11 07:01:32         3    중랑센터      0
# 4  SPB-31324  2021-12-15 16:02:04         3    중랑센터      0
#
#                   반납일시  반납대여소번호             반납대여소명  반납거치대  이용시간     이용거리
# 0  2021-12-01 09:58:57      646  장한평역 1번출구 (국민은행앞)      0    13     0.00
# 1  2021-12-05 16:07:58      529       장한평역 8번 출구 앞      0     5     0.00
# 2  2021-12-10 22:40:27     1332       석계역 5번출구 건너편      0    38  8710.00
# 3  2021-12-11 07:11:11      540    군자역 7번출구 베스트샵 앞      0     9     0.00
# 4  2021-12-15 16:13:21      540    군자역 7번출구 베스트샵 앞      0    11  2161.63

# %%
# 공공자전거 대여소 정보
bike_station = pd.read_csv('data/bike_station.csv')
bike_station.tail()
# Out:
#       대여소 번호                   보관소(대여소)명  자치구  \
# 2581    5070  마곡13단지힐스테이트마스터 후문(1320동 앞)  강서구
# 2582    5072                  김포공항입구 교통섬  강서구
# 2583    5073                우장산역 헤링턴타워 앞  강서구
# 2584    5074                 마곡동 주니어마곡점앞  강서구
# 2585    5075                      템퍼 목동점  강서구
#
#                                         상세주소         위도          경도  \
# 2581  서울시 강서구 마곡중앙1로 71 마곡13단지힐스테이트마스터 후문 인근  37.556763  126.818695
# 2582                                공항동 74-5  37.561546  126.807083
# 2583                              화곡동 1013-3  37.546619  126.836235
# 2584                          강서구 마곡동 798-17  37.558235  126.825760
# 2585                          강서구 등촌동 649-14  37.551884  126.863571
#
#             설치시기  거치대수(LCD)  거치대수(QR) 운영방식
# 2581  2021.11.11        NaN      15.0   QR
# 2582   2021.9.28        NaN      10.0   QR
# 2583  2021.10.20        NaN       6.0   QR
# 2584  2021.11.19        NaN      10.0   QR
# 2585  2021.11.19        NaN      10.0   QR

# %%
# Tour API 관광지 정보
tour_list = pd.read_csv('data/tour_list.csv')
tour_list.head()
# Out:
#   addr1 addr2   createdtime  langCheck langCode        mapX       mapY  \
# 0    서울   종로구  2.020000e+13       1111       ko  126.986818  37.575704
# 1    서울    중구  2.020000e+13       1111       ko  126.976485  37.564977
# 2    서울   종로구  2.020000e+13       1111       ko  126.967911  37.568335
# 3    서울   종로구  2.020000e+13       1111       ko  126.967911  37.568335
# 4    서울   종로구  2.020000e+13       1111       ko  126.970830  37.578601
#
#    modifiedtime themeCategory   tid   title  tlid  imageUrl
# 0  2.020000e+13           오쾌남   639     운현궁  1527       NaN
# 1  2.020000e+13           오쾌남   640     덕수궁  1528       NaN
# 2  2.020000e+13           NaN  1365  서울 경교장  2267       NaN
# 3  2.020000e+13   김영하의 서촌골목여행  1365  홍건익 가옥  2560       NaN
# 4  2.020000e+13   김영하의 서촌골목여행  1366   이상의 집  2561       NaN

# %%
# 관광 데이터랩 관광지 정보 ( tour_spot_detail )
tour_list = pd.read_csv('data/tour_spot_merge.csv')
tour_list.head()
# Out:
#    순위            관광지명                  주소    분류        lat         lon
# 0   5     국립현대미술관/서울관     서울 종로구 삼청로 30-0  문화시설  37.578628  126.980088
# 1  10  서울특별시교육청/정독도서관   서울 종로구 북촌로5길 48-0  문화시설  37.581265  126.983870
# 2  15         서울역사박물관    서울 종로구 새문안로 55-0  문화시설  37.570497  126.971075
# 3  20          청와대사랑채  서울 종로구 효자로13길 45-0  문화시설  37.582545  126.973059
# 4  27         국립고궁박물관     서울 종로구 효자로 12-0  문화시설  37.576592  126.974975

# %%
# 전처리_#1
bike_station_dict = defaultdict(list)

id = bike_station['대여소 번호'].tolist()
address = bike_station['자치구'].tolist()
lat = bike_station['위도'].tolist()
lon = bike_station['경도'].tolist()

for i in range(len(bike_station)):
  bike_station_dict[id[i]].append(address[i])
  bike_station_dict[id[i]].append(lat[i])
  bike_station_dict[id[i]].append(lon[i])

# %%
# 전처리_#2
origination_name = bike['대여 대여소명'].tolist()
origination_list = bike['대여 대여소번호'].tolist()
destination_name = bike['반납대여소명'].tolist()
destination_list = bike['반납대여소번호'].tolist()

o_name = []
o_lat = []
o_lon = []
o_addr = []
d_name = []
d_lat = []
d_lon = []
d_addr = []
count = []
path_list = []

for i in range(len(bike)):
  if bike_station_dict.get(origination_list[i]) and bike_station_dict.get(destination_list[i]):
    if bike_station_dict.get(origination_list[i])[0] == '중구' or bike_station_dict.get(origination_list[i])[0] == '종로구':
      if bike_station_dict.get(destination_list[i])[0] == '중구' or bike_station_dict.get(destination_list[i])[0] == '종로구':
        if origination_list[i] != destination_list[i]:
          temp = []

          temp.append(origination_name[i])
          temp.append(bike_station_dict[origination_list[i]][0])
          temp.append(bike_station_dict[origination_list[i]][1])
          temp.append(bike_station_dict[origination_list[i]][2])
          temp.append(destination_name[i])
          temp.append(bike_station_dict[destination_list[i]][0])
          temp.append(bike_station_dict[destination_list[i]][1])
          temp.append(bike_station_dict[destination_list[i]][2])

          path_list.append(str(temp))

path_stat = Counter(path_list)

for key, value in path_stat.items():
  if value > 10:
    key = eval(key)
    o_name.append(key[0])
    o_addr.append(key[1])
    o_lat.append(key[2])
    o_lon.append(key[3])
    d_name.append(key[4])
    d_addr.append(key[5])
    d_lat.append(key[6])
    d_lon.append(key[7])
    count.append(value)

preprocessing_data = pd.DataFrame({
  'o_name': o_name,
  'o_addr': o_addr,
  'o_lat': o_lat,
  'o_lon': o_lon,
  'd_name': d_name,
  'd_addr': d_addr,
  'd_lat': d_lat,
  'd_lon': d_lon,
  'visited': count
})

# %%
# 전처리 데이터 Check
preprocessing_data.to_csv('data/prerprocessing.csv', index=False, encoding='utf-8')
preprocessing_data.head(10)
# Out:
#   o_name o_addr     o_lat       o_lon           d_name d_addr      d_lat  \
# 0  정동사거리     중구  37.56805  126.969231            정동길입구     중구  37.565052
# 1  정동사거리     중구  37.56805  126.969231  시청역(2호선) 9번출구 뒤     중구  37.563229
# 2  정동사거리     중구  37.56805  126.969231       경희궁 자이 3단지    종로구  37.567490
# 3  정동사거리     중구  37.56805  126.969231         종각역 5번출구    종로구  37.569836
# 4  정동사거리     중구  37.56805  126.969231             부산은행     중구  37.566471
# 5  정동사거리     중구  37.56805  126.969231      광화문역 6번출구 옆    종로구  37.569889
# 6  정동사거리     중구  37.56805  126.969231           KG타워 앞     중구  37.563396
# 7  정동사거리     중구  37.56805  126.969231        광화문 S타워 앞    종로구  37.569969
# 8  정동사거리     중구  37.56805  126.969231         독립문역 사거리    종로구  37.572029
# 9  정동사거리     중구  37.56805  126.969231        서울도시건축전시관     중구  37.567017
#
#         d_lon  visited
# 0  126.973404       67
# 1  126.974838       36
# 2  126.965919       16
# 3  126.982658       16
# 4  126.979256       25
# 5  126.976456       24
# 6  126.968941       13
# 7  126.973938       49
# 8  126.960785       17
# 9  126.976837       40

# %%
def get_near_station(cur_lat: int, cur_lon: int) -> list:
  '''
  현재 위치 기준으로 가장 가까운 대여소 정보를 반환합니다.
  '''
  # id, address, lat, lon
  best = ['', '', 0, 0]
  min_dist = float('inf')

  for i in range(len(bike_station)):
    dist = ((cur_lat - bike_station.loc[i, '위도']) ** 2) + ((cur_lon - bike_station.loc[i, '경도']) ** 2) ** 1/2
    if dist < min_dist:
      min_dist = dist
      best[0] = bike_station.loc[i, '대여소 번호']
      best[1] = bike_station.loc[i, '보관소(대여소)명']
      best[2] = bike_station.loc[i, '위도']
      best[3] = bike_station.loc[i, '경도']

  return best

def get_tour_spot(cur_lat: int, cur_lon: int) -> list:
  '''
  현재 위치 기준으로 가장 가까운 관광지 경로를 반환합니다.
  '''
  # id, address, lat, lon
  best = ['', '', 0, 0]
  min_dist = float('inf')

  for i in range(len(tour_list)):
    visited = False
    for row in recomendation_list:
      if row[1] == tour_list.loc[i, '관광지명']:
        visited = True
        break
      
    if not visited:  
      dist = ((cur_lat - tour_list.loc[i, 'lat']) ** 2) + ((cur_lon - tour_list.loc[i, 'lon']) ** 2) ** 1/2
      if dist < min_dist:
        min_dist = dist
        best[0] = tour_list.loc[i, '관광지명']
        best[1] = tour_list.loc[i, '관광지명']
        best[2] = tour_list.loc[i, 'lon']
        best[3] = tour_list.loc[i, 'lat']

  return best


def get_station(cur_lat: int, cur_lon: int) -> list:
  '''
  해당 대여소 기준으로 ( 이동 거리 100M 이내 ) or 없다면 가장 가까운 Destination 경로를 탐색합니다
  '''
  # id, address, lat, lon
  best = ['', '', 0, 0]
  max_visited = float('-inf')

  for i in range(len(preprocessing_data)):
    if preprocessing_data.loc[i, 'o_lat'] == cur_lat and preprocessing_data.loc[i, 'o_lon'] == cur_lon:
      dist = ((preprocessing_data.loc[i, 'o_lat'] - preprocessing_data.loc[i, 'd_lat']) ** 2 + \
            (preprocessing_data.loc[i, 'o_lon'] - preprocessing_data.loc[i, 'd_lon']) ** 2) ** 1/2
      if dist < 0.1 and preprocessing_data.loc[i, 'visited'] > max_visited:
        max_visited = preprocessing_data.loc[i, 'visited']
        best[0] = preprocessing_data.loc[i, 'd_name']
        best[1] = preprocessing_data.loc[i, 'd_addr']
        best[2] = preprocessing_data.loc[i, 'd_lat']
        best[3] = preprocessing_data.loc[i, 'd_lon']
  
  return best

# %%
# Rule-Based
# 1. 시작 좌표 및 추천 관광지 경로 개수 입력 받기, 명동 관광정보센터 -> lat: 37.565365, lon: 126.984960
lat, lon, num = 37.578628, 126.980088, 15
recomendation_list = []
recomendation_list.append(['1', '국립현대미술관', lon, lat])
cur_stat_pos = get_near_station(lat, lon)

for i in range(num):
  cur_stat_pos = get_station(cur_stat_pos[2], cur_stat_pos[3])
  cur_tour_pos = get_tour_spot(cur_stat_pos[2], cur_stat_pos[3])
  recomendation_list.append(cur_tour_pos)

for i in range(len(recomendation_list)):
  recomendation_list[i][0] = i+1

print(recomendation_list)
# Out:
# [[1, '국립현대미술관', 126.980088, 37.578628], [2, '서울공예박물관', 126.983533363501, 37.5766481740232], [3, 'PKM갤러리', 126.980082350686, 37.5840916531266], [4, '국립고궁박물관', 126.974974825074, 37.5765916191985], [5, '서울역사박물관', 126.97107522045, 37.5704968494713], [6, '대한민국역사박물관', 126.978339442463, 37.5737136067193], [7, '서울특별시교육청어린이도서관', 126.968231878405, 37.5762858214854], [8, '갤러리라메르', 126.984868085947, 37.5725819833564], [9, '종로문화체육센터', 126.964661018954, 37.5742098160357], [10, '경인미술관', 126.985723489033, 37.5745908579478], [11, '그라운드시소/서촌', 126.972916073118, 37.577840393396], [12, '갤러리현대', 126.979823330741, 37.5773056844787], [13, '서울특별시교육청종로도서관', 126.966466827575, 37.5764496746814], [14, '경찰박물관', 126.962196007118, 37.5720572964048], [15, '국립현대미술관/서울관', 126.980087994867, 37.5786280284849], [16, '국립현대미술관서울관', 126.980087994867, 37.5786280284849]]

# %%
result_list = []
for i in range(len(recomendation_list) - 1):
  temp = []
  temp.append(recomendation_list[i][0])
  temp.append(recomendation_list[i][1])
  temp.append(recomendation_list[i][3])
  temp.append(recomendation_list[i][2])

  temp.append(recomendation_list[i+1][0])
  temp.append(recomendation_list[i+1][1])
  temp.append(recomendation_list[i+1][3])
  temp.append(recomendation_list[i+1][2])
  
  result_list.append(temp)

# %%
result = pd.DataFrame(result_list)
result.columns = ['o_idx', 'o_name', 'o_lat', 'o_lon', 'd_idx', 'd_name', 'd_lat', 'd_lon']
result.to_csv('data/result_third.csv', index=False)
result.head(20)
# Out:
#     o_idx          o_name      o_lat       o_lon  d_idx          d_name  \
# 0       1         국립현대미술관  37.578628  126.980088      2         서울공예박물관
# 1       2         서울공예박물관  37.576648  126.983533      3          PKM갤러리
# 2       3          PKM갤러리  37.584092  126.980082      4         국립고궁박물관
# 3       4         국립고궁박물관  37.576592  126.974975      5         서울역사박물관
# 4       5         서울역사박물관  37.570497  126.971075      6       대한민국역사박물관
# 5       6       대한민국역사박물관  37.573714  126.978339      7  서울특별시교육청어린이도서관
# 6       7  서울특별시교육청어린이도서관  37.576286  126.968232      8          갤러리라메르
# 7       8          갤러리라메르  37.572582  126.984868      9        종로문화체육센터
# 8       9        종로문화체육센터  37.574210  126.964661     10           경인미술관
# 9      10           경인미술관  37.574591  126.985723     11       그라운드시소/서촌
# 10     11       그라운드시소/서촌  37.577840  126.972916     12           갤러리현대
# 11     12           갤러리현대  37.577306  126.979823     13   서울특별시교육청종로도서관
# 12     13   서울특별시교육청종로도서관  37.576450  126.966467     14           경찰박물관
# 13     14           경찰박물관  37.572057  126.962196     15     국립현대미술관/서울관
# 14     15     국립현대미술관/서울관  37.578628  126.980088     16      국립현대미술관서울관
#
#         d_lat       d_lon
# 0   37.576648  126.983533
# 1   37.584092  126.980082
# 2   37.576592  126.974975
# 3   37.570497  126.971075
# 4   37.573714  126.978339
# 5   37.576286  126.968232
# 6   37.572582  126.984868
# 7   37.574210  126.964661
# 8   37.574591  126.985723
# 9   37.577840  126.972916
# 10  37.577306  126.979823
# 11  37.576450  126.966467
# 12  37.572057  126.962196
# 13  37.578628  126.980088
# 14  37.578628  126.980088
